# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales_082020.csv', encoding="utf8")
df.head(5)
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
df.index

# %%
len(df.seller_id.value_counts())
# Out:
# 114227

# %%
df["seller_country" == "EUR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.head(5)
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.groupby("currency")["EUR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7876/1334350514.py in <module>
# ----> 1 df.groupby("currency")["EUR"]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: EUR'

# %%
df[df.currency == "EUR"].sum()
# Out:
# C:\Users\Burya\AppData\Local\Temp/ipykernel_7876/2607468854.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df.currency == "EUR"].sum()
# buyer_id          oagt2ozal7xpbfdqczlkzos594tze5x1bjyofhp5xpbfdq...
# buyer_country     IEITITITITITITITITITITITITITITITITITITITITITIT...
# seller_id         b57xo98qspoetwqzspoetwqzspoetwqz8b0q1eqs8b0q1e...
# seller_country    IEITITITITITITITITITITITITITITITITITITITITITIT...
# product_code      2l6ze3xh4royykdmbrywpjx4vlbfdpb8pke2ru1iggf0v7...
# currency          EUREUREUREUREUREUREUREUREUREUREUREUREUREUREURE...
# price                                                     275837.69
# date              2020-08-082020-08-092020-08-082020-08-062020-0...
# dtype: object

# %%
df.groupby("currency")["price"].sum()
# Out:
# currency
# AUD     325563.44
# BRL         34.92
# CAD      65101.80
# CHF       5974.74
# CZK       3923.18
# DKK       4853.44
# EUR     275837.69
# GBP    3449449.49
# HKD        108.13
# HUF      36919.18
# ILS         33.80
# JPY      39722.66
# MXN        389.47
# MYR        263.30
# NOK       3168.34
# NZD      10532.85
# PLN        693.36
# SEK      10903.22
# SGD        443.37
# THB       1223.72
# TWD         42.81
# USD    2504544.82
# Name: price, dtype: float64

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.groupby("brand")["price"].sum().sort_values(ascending=False)
# Out:
# brand
# Nike                  373559.23
# Adidas                110351.33
# American Vintage      105227.77
# Brandy Melville       100055.63
# Dr. Martens            84418.65
#                         ...
# Ann Demeulemeester         6.19
# 3LAB                       5.57
# Popular Sports             5.26
# 360 Cashmere               3.36
# 36572                      1.12
# Name: price, Length: 1134, dtype: float64

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.category.value_counts()
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Sports equipment       413
# Underwear              177
# Transportation          90
# UNSPECIFIED              7
# Name: category, dtype: int64

# %%
df[df.brand == "NaN"].value_counts(dropna=True)
# Out:
# Series([], dtype: int64)

# %%
df.brand.value_counts(dropna=True)
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Preen                    1
# Wacoal                   1
# Shu Uemura               1
# Parker                   1
# Vita Fede                1
# Name: brand, Length: 1134, dtype: int64

# %%
df[df.brand == "NaN"]
# Out:
# Empty DataFrame
# Columns: [buyer_id, buyer_country, seller_id, seller_country, product_code, category, brand, currency, price, date]
# Index: []

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.category.value_counts(dropna=True)
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Sports equipment       413
# Underwear              177
# Transportation          90
# UNSPECIFIED              7
# Name: category, dtype: int64

# %%
df.category.Jewellery
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7876/2645430974.py in <module>
# ----> 1 df.category.Jewellery
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Jewellery'

# %%
df.head(20)
# Out:
#       buyer_id buyer_country seller_id seller_country  product_code  \
# 0   qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1   o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2   sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3   o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4   o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# 5   bf6dqe8we7            GB  dpkx192v             GB  cmwn68orhjq8
# 6   o79pns1qwo            GB  9p2ansc9             GB  dsz1fy32ry6y
# 7   bob9rlo4lb            GB  9p2ansc9             GB  jfncu4dmfnoc
# 8   bob9rlo4lb            GB  9p2ansc9             GB  ssmpsnfvopu9
# 9   thxau27e0a            GB  9p2ansc9             GB  0dv7zg0lu2xc
# 10  762bgx2nhz            GB  9p2ansc9             GB  noptuewx9l22
# 11  762bgx2nhz            GB  9p2ansc9             GB  3omdouiqh11l
# 12  p9vxp94nfh            IE  9p2ansc9             GB  95a5rc0jjtbz
# ...

# %%
df.category.value_counts().head(20)
# Out:
# Tops - Womens        45450
# Tops - Mens          32611
# Bottoms - Womens     30001
# Shoes                21764
# Accessories          21153
# Dresses              19238
# Jewellery            14923
# Beauty                8746
# Other                 6599
# Outerwear             6321
# Bottoms - Mens        5763
# Lingerie              5301
# Outerwear - Mens      4156
# Tech                  3496
# Home                  3477
# Music                 2510
# Kids                  2135
# Art                   1777
# Books & magazines     1081
# Film                   466
# Name: category, dtype: int64

# %%
df.groupby("brand")["price"].aggregate(["mean","min","max"])
# Out:
#                       mean    min     max
# brand
# & Other Stories  30.566358   1.05  625.85
# 032c             34.252727   1.11  213.30
# 11 Degrees       13.113939   1.08   52.10
# 1822 Denim       18.847500   3.83   42.76
# 3.1 Phillip Lim  35.616000   6.59  153.54
# ...                    ...    ...     ...
# ghd              56.146000   5.67  171.24
# kensie           23.450000  23.45   23.45
# liquid blue      46.085962   5.52  115.76
# mixxmix          18.787500   5.52   38.60
# philosophy       26.585000  14.16   41.64
#
# [1134 rows x 3 columns]

# %%
df.groupby("brand")["price"] == df.
# Out:
# 0         19.11
# 1         15.92
# 2          6.37
# 3         25.27
# 4          8.90
#           ...
# 235608     6.79
# 236069     5.66
# 236255    11.25
# 237067    52.67
# 237306    11.10
# Name: price, Length: 4465, dtype: float64

# %%
df[df["category"] == "Jewellery"].value_counts()
# Out:
# buyer_id    buyer_country  seller_id  seller_country  product_code  category   brand            currency  price  date
# 026yj47w7b  US             67kyc6i0   US              ojyn0vb4n2l1  Jewellery  ALEX AND ANI     USD       37.14  2020-08-06    1
# ntt7pibwfj  US             xqjg45qk   US              rpnfy49txnup  Jewellery  Brandy Melville  USD       7.14   2020-08-04    1
# nwuypkha8n  US             ei5irf4n   US              a7hpd20ngvg6  Jewellery  Unbranded        USD       7.99   2020-08-09    1
# nvsbo0ya6f  GB             d8iftp51   GB              qxxa84ubv48k  Jewellery  PANDORA          GBP       21.80  2020-08-05    1
# nvqk8ktnu5  GB             ftde6aff   GB              tmj2cpmssduj  Jewellery  PANDORA          GBP       13.60  2020-08-03    1
#                                                                                                                               ..
# ...

# %%
df.groupby("category")["brand"].count()
# Out:
# category
# Accessories           8656
# Art                      0
# Beauty                4348
# Books & magazines        0
# Bottoms - Mens        4431
# Bottoms - Womens     18252
# Dresses              10604
# Film                     1
# Home                     1
# Jewellery             1398
# Kids                   133
# Lingerie              1906
# Music                    0
# Other                  101
# Outerwear             3521
# Outerwear - Mens      2994
# Shoes                16532
# Sports equipment        12
# Tech                  1641
# Tops - Mens          20942
# Tops - Womens        23844
# Transportation           1
# UNSPECIFIED              0
# Underwear                6
# Name: brand, dtype: int64

# %%
df[df["category"] == "Jewellery"].brand.value_counts(dropna=False).head(20)
# Out:
# NaN                  13525
# PANDORA                493
# Brandy Melville        190
# Vivienne Westwood       94
# Tiffany & Co.           56
# Unbranded               56
# Michael Kors            43
# Swarovski               33
# Hot Topic               28
# Thomas Sabo             27
# Topshop                 27
# ALEX AND ANI            26
# Forever 21              22
# Dior                    21
# Links of London         16
# New Look                15
# Emporio Armani          15
# ASOS                    13
# Marc Jacobs             13
# Gucci                   12
# Name: brand, dtype: int64

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price        date
# 0           Dresses               NaN      GBP  19.11  2020-08-03
# 1         Outerwear  Adidas Originals      GBP  15.92  2020-08-09
# 2       Tops - Mens               NaN      GBP   6.37  2020-08-07
# 3       Tops - Mens          Berghaus      GBP  25.27  2020-08-09
# 4  Bottoms - Womens               NaN      GBP   8.90  2020-08-09

# %%
df.currency
# Out:
# 0         GBP
# 1         GBP
# 2         GBP
# 3         GBP
# 4         GBP
#          ...
# 237666    GBP
# 237667    USD
# 237668    GBP
# 237669    GBP
# 237670    USD
# Name: currency, Length: 237671, dtype: object

# %%
df[df["currency"] == "EUR"].price.sum()
# Out:
# 275837.69
