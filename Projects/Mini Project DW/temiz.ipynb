# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
from datetime import datetime
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
bulut = pd.read_csv('store_sharing.csv', encoding="windows-1252")
bulut.head(5)
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
bulut.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
# season
sns.countplot(x="season",data=bulut)
plt.show()

# %%
# is_holiday
sns.countplot(x="is_holiday",data=bulut)
plt.show()

# %%
# is_weekend
sns.countplot(x="is_weekend",data=bulut)
plt.show()

# %%
# weather_code
sns.countplot(x="weather_code",data=bulut)
plt.show()

# %%
bulut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
print(bulut.timestamp.dtype)
# Out:
# object

# %% [markdown]
# Objecti datetime a degiştireceğiz

# %%
bulut.timestamp = pd.to_datetime(bulut.timestamp)

# %%
bulut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
bulut.timestamp = pd.to_datetime(bulut.timestamp)
bulut.set_index("timestamp", inplace=True)
bulut.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
bulut.head(3)
# Out:
#                      cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5  96.5         0.0           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0

# %%
from datetime import datetime
bulut["year_month"] = bulut.index.strftime("%Y-%m")
bulut["year"] =  bulut.index.year
bulut["month"] =  bulut.index.month
bulut["day_of_month"] =  bulut.index.day
bulut["day_of_week"] =  bulut.index.dayofweek
bulut["hour"] = bulut.index.hour

# %%
bulut.head(4)
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# ...

# %%
bulut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   year_month    17414 non-null  object
#  10  year          17414 non-null  int64
#  11  month         17414 non-null  int64
#  12  day_of_month  17414 non-null  int64
#  13  day_of_week   17414 non-null  int64
#  14  hour          17414 non-null  int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 2.1+ MB

# %%
bulut.head(3)
# Out:
#             timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5  96.5         0.0           1.0
#
#    is_holiday  is_weekend  season year_month  year month  day_of_month  \
# 0         0.0         1.0     3.0    2015-01   1.0    01           1.0
# 1         0.0         1.0     3.0    2015-01   1.0    01           1.0
# 2         0.0         1.0     3.0    2015-01   1.0    01           1.0
#
#   day_of_week hour
# 0           0   00
# 1           0   01
# 2           0   02

# %% [markdown]
# \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\

# %%
fig, ax = plt.subplots(figsize=(14, 10))
ax = sns.heatmap(bulut.corr(),annot=True, cmap="coolwarm")

# %%
fig, ax = plt.subplots(figsize=(2.5, 10))
ax = sns.heatmap(bulut.corr()[["cnt"]].sort_values("cnt")[::-1],annot=True,cmap="Blues")

# %%
bulut.plot.bar(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='t1'>
# Error in callback <function flush_figures at 0x000001F57FC72940> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
# ...

# %%
bulut.head(2)
# Out:
#                      cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1

# %%
fig, ax= plt.subplots(figsize=(20,5))
zaman=bulut.year_month
ax= sns.lineplot(y="cnt",x="year_month",data=bulut,err_style=None)
ax.set_xticklabels(zaman, rotation=90)
plt.show()

# %%
fig, ax= plt.subplots(figsize=(15,5))

zaman=bulut.year_month
ax= sns.lineplot(y="cnt",x="year_month",data=bulut,err_style=None)
ax.set_xticklabels(zaman, rotation=90)
plt.show()

# %%
fig, ax= plt.subplots(figsize=(12,7))
ax= sns.lineplot(y="cnt",x="month",data=bulut)

# %%
fig, ax= plt.subplots(figsize=(15,5))
ax= sns.pointplot(y="cnt",x="month",data=bulut)
