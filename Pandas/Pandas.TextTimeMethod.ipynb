# %%
import numpy as np
import pandas as pd
from datetime import timedelta
import seaborn as sns

# %%
# 9.10.2021

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.sex.str.contains("male")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: sex, Length: 891, dtype: bool

# %%
df.sex.str.contains("female") #kadin olanlarda True geldi geri kalan false
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: sex, Length: 891, dtype: bool

# %%
df[df.sex.str.contains("female")] #filtreledik
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.sex=="female"]  #bu sekilde de labilirim
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sex= df.sex.str.upper()  #df sex sutununa git ve sex gurubuna upper uygula
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df.sex=df.sex.str.upper()
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df.sex=df.sex.replace("Male","male")
df.sex
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3      FEMALE
# 4        MALE
#         ...
# 886      MALE
# 887    FEMALE
# 888    FEMALE
# 889      MALE
# 890      MALE
# Name: sex, Length: 891, dtype: object

# %%
df=df.replace("male","MALE")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   Third
# 1           1       1  FEMALE  38.0      1      0  71.2833        C   First
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   Third
# 3           1       1  FEMALE  35.0      1      0  53.1000        S   First
# 4           0       3    MALE  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  27.0      0      0  13.0000        S  Second
# 887         1       1  FEMALE  19.0      0      0  30.0000        S   First
# 888         0       3  FEMALE   NaN      1      2  23.4500        S   Third
# 889         1       1    MALE  26.0      0      0  30.0000        C   First
# 890         0       3    MALE  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["class"]=df["class"].str.swapcase()
df["class"]
# Out:
# 0       tHIRD
# 1       fIRST
# 2       tHIRD
# 3       fIRST
# 4       tHIRD
#         ...
# 886    sECOND
# 887     fIRST
# 888     tHIRD
# 889     fIRST
# 890     tHIRD
# Name: class, Length: 891, dtype: object

# %%
df["age"].str.isnumeric()  #string methodunu yalniz string ler icin kullanabilirsiniz
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8864/2302271757.py in <module>
# ----> 1 df["age"].str.isnumeric()  #string methodunu yalniz string ler icin kullanabilirsiniz
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# ...

# %%
df["age"].astype("string").str.isnumeric() #stringe ceviriyoruz
#<NA> numericdir
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     <NA>
# 889    False
# 890    False
# Name: age, Length: 891, dtype: boolean

# %%
df["age"]=df["age"].replace(np.nan,"unknown")
df.age.value_counts()
#177 tane bilinmeye var
# Out:
# unknown    891
# Name: age, dtype: int64

# %%
df["age"]=df["age"].map({"unknown":"unk"})
df.age.value_counts()  #map ile bu sefer unknown lari "unk " olrak degistirdik
# Out:
# Series([], Name: age, dtype: int64)

# %%
df.age  #map de bizim sadece belirledigimiz olanlari degistirir
#aksi takdirde geri kalan tum veriyi NaN yapar
#
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 886    NaN
# 887    NaN
# 888    unk
# 889    NaN
# 890    NaN
# Name: age, Length: 891, dtype: object

# %%
df.age #data setini geri okutduk #yukarida hepsini oku var
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   tHIRD
# 1           1       1  FEMALE  38.0      1      0  71.2833        C   fIRST
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   tHIRD
# 3           1       1  FEMALE  35.0      1      0  53.1000        S   fIRST
# 4           0       3    MALE  35.0      0      0   8.0500        S   tHIRD
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  27.0      0      0  13.0000        S  sECOND
# 887         1       1  FEMALE  19.0      0      0  30.0000        S   fIRST
# 888         0       3  FEMALE   NaN      1      2  23.4500        S   tHIRD
# 889         1       1    MALE  26.0      0      0  30.0000        C   fIRST
# 890         0       3    MALE  32.0      0      0   7.7500        Q   tHIRD
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.embark_town.str.contains("bourg")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.contains("town")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.endswith("town")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.startswith("Cher")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.value_counts(dropna=False)
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# NaN              2
# Name: embark_town, dtype: int64

# %%
df.embark_town.fillna(df.embark_town.mode([0]),inplace=True)

# %%
df[df.age.astype("string").str.startswith("2")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  22.0      1      0   7.2500        S   tHIRD
# 2           1       3  FEMALE  26.0      0      0   7.9250        S   tHIRD
# 7           0       3    MALE   2.0      3      1  21.0750        S   tHIRD
# 8           1       3  FEMALE  27.0      0      2  11.1333        S   tHIRD
# 12          0       3    MALE  20.0      0      0   8.0500        S   tHIRD
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  FEMALE  22.0      0      0  10.5167        S   tHIRD
# 883         0       2    MALE  28.0      0      0  10.5000        S  sECOND
# 884         0       3    MALE  25.0      0      0   7.0500        S   tHIRD
# 886         0       2    MALE  27.0      0      0  13.0000        S  sECOND
# 889         1       1    MALE  26.0      0      0  30.0000        C   fIRST
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
##########################

# %%
#       FIND     FIND ALL

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    MALE  NaN      1      0   7.2500        S   tHIRD
# 1           1       1  FEMALE  NaN      1      0  71.2833        C   fIRST
# 2           1       3  FEMALE  NaN      0      0   7.9250        S   tHIRD
# 3           1       1  FEMALE  NaN      1      0  53.1000        S   fIRST
# 4           0       3    MALE  NaN      0      0   8.0500        S   tHIRD
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    MALE  NaN      0      0  13.0000        S  sECOND
# 887         1       1  FEMALE  NaN      0      0  30.0000        S   fIRST
# 888         0       3  FEMALE  NaN      1      2  23.4500        S   tHIRD
# 889         1       1    MALE  NaN      0      0  30.0000        C   fIRST
# 890         0       3    MALE  NaN      0      0   7.7500        Q   tHIRD
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.age.astype("string").str.find("unk")  #na ler normel de unk di 
#calistirma hatalarindan dolayi eski haline geri dondu
# Out:
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
#        ...
# 886      -1
# 887      -1
# 888    <NA>
# 889      -1
# 890      -1
# Name: age, Length: 891, dtype: Int64

# %%
df.embark_town.str.findall("Queenstown")
# Out:
# 0                []
# 1                []
# 2                []
# 3                []
# 4                []
#            ...
# 886              []
# 887              []
# 888              []
# 889              []
# 890    [Queenstown]
# Name: embark_town, Length: 891, dtype: object

# %%
df.embark_town.str.findall("Queenstown").value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []              812
# [Queenstown]     77
# Name: embark_town, dtype: int64

# %%
df.embark_town.str.find("Queenstown")
# Out:
# 0     -1.0
# 1     -1.0
# 2     -1.0
# 3     -1.0
# 4     -1.0
#       ...
# 886   -1.0
# 887   -1.0
# 888   -1.0
# 889   -1.0
# 890    0.0
# Name: embark_town, Length: 891, dtype: float64

# %%
sns.get_dataset_names()  #seaborn kutuphanesinin datasetleri
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("flights")

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.year=pd.to_datetime(df.year)   #df in year inin degistirdik

# %%
df.year #int den datetime object e degisti
# Out:
# 0     1970-01-01 00:00:00.000001949
# 1     1970-01-01 00:00:00.000001949
# 2     1970-01-01 00:00:00.000001949
# 3     1970-01-01 00:00:00.000001949
# 4     1970-01-01 00:00:00.000001949
#                    ...
# 139   1970-01-01 00:00:00.000001960
# 140   1970-01-01 00:00:00.000001960
# 141   1970-01-01 00:00:00.000001960
# 142   1970-01-01 00:00:00.000001960
# 143   1970-01-01 00:00:00.000001960
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
df.year.dt.day_of_week
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 139    3
# 140    3
# 141    3
# 142    3
# 143    3
# Name: year, Length: 144, dtype: int64

# %%
df.year.dt.days_in_month
# Out:
# 0      31
# 1      31
# 2      31
# 3      31
# 4      31
#        ..
# 139    31
# 140    31
# 141    31
# 142    31
# 143    31
# Name: year, Length: 144, dtype: int64

# %%
df.year.value_counts()
# Out:
# 1970-01-01 00:00:00.000001949    12
# 1970-01-01 00:00:00.000001950    12
# 1970-01-01 00:00:00.000001951    12
# 1970-01-01 00:00:00.000001952    12
# 1970-01-01 00:00:00.000001953    12
# 1970-01-01 00:00:00.000001954    12
# 1970-01-01 00:00:00.000001955    12
# 1970-01-01 00:00:00.000001956    12
# 1970-01-01 00:00:00.000001957    12
# 1970-01-01 00:00:00.000001958    12
# 1970-01-01 00:00:00.000001959    12
# 1970-01-01 00:00:00.000001960    12
# Name: year, dtype: int64

# %%
df.year = pd.to_datetime(df.year, format="%Y")
df.year    #format belirtmeyince kalici olrak int den datetime a degistirmiyor.
# Out:
# 0     1970-01-01 00:00:00.000001949
# 1     1970-01-01 00:00:00.000001949
# 2     1970-01-01 00:00:00.000001949
# 3     1970-01-01 00:00:00.000001949
# 4     1970-01-01 00:00:00.000001949
#                    ...
# 139   1970-01-01 00:00:00.000001960
# 140   1970-01-01 00:00:00.000001960
# 141   1970-01-01 00:00:00.000001960
# 142   1970-01-01 00:00:00.000001960
# 143   1970-01-01 00:00:00.000001960
# Name: year, Length: 144, dtype: datetime64[ns]

# %%
df.year.dt.year
# Out:
# 0      1970
# 1      1970
# 2      1970
# 3      1970
# 4      1970
#        ...
# 139    1970
# 140    1970
# 141    1970
# 142    1970
# 143    1970
# Name: year, Length: 144, dtype: int64

# %%
###olmadi 1970 de kaldi

# %%
current_date=datetime.now()
current_date
# Out:
# datetime.datetime(2021, 10, 9, 11, 43, 16, 224959)

# %%
current_date.month   #10 ay dayim suan
# Out:
# 10

# %%
current_date.day
# Out:
# 9

# %%
current_date.today() #today ile now aslinda ayni seyi veriyor
# Out:
# datetime.datetime(2021, 10, 9, 11, 44, 32, 991526)

# %%
#strftime() and strptime()

# %%
#current time zaten parcalanmis sekilde

# %%
current_date.strftime(("%d" "%B" "%Y"))#istedigimiz format da formatliyoruz
# Out:
# '09October2021'

# %%
date = current_date.strftime("%d"+" "+"%B"+" "+"%Y")

# %%
datetime.strptime(date, "%d %B %Y")
# Out:
# datetime.datetime(2021, 10, 9, 0, 0)

# %%
datetime.strptime(date, "%d %B %Y")  #date e uzun veya kisa tarih verirsek ona gore buyuk Y Kucuk y kullanimi degisir
# Out:
# datetime.datetime(2021, 10, 9, 0, 0)

# %%
#time delta
#mevcut tarihimize ekleme cikartma da kullaniliyor

# %%
date
# Out:
# '09 October 2021'

# %%
date-timedelta(weeks=1)  #hata verdi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8864/2927921747.py in <module>
# ----> 1 date-timedelta(weeks=1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'datetime.timedelta'

# %%
current_date.now()-timedelta(weeks=1)  #
# Out:
# datetime.datetime(2021, 10, 2, 12, 11, 3, 266754)

# %%
current_date.today()-timedelta(days=3) #bunu ayrica formatliya biliriz
# Out:
# datetime.datetime(2021, 10, 6, 12, 12, 49, 770995)

# %%
(current_date.today()-timedelta(days=3)).strftime("%d %B %Y")

#daha sik durmasi acisindan strf time ile sadelestirebiliriz
# Out:
# '06 October 2021'

# %%
#####DATA INPUT OUTPUT####

# %%
df= pd.read_csv("example.csv",skiprows=1)  #bir satir atlattik
df
# Out:
#     0   1   2   3
# 0   4   5   6   7
# 1   8   9  10  11
# 2  12  13  14  15

# %%
df= pd.read_csv("example.csv",skiprows=2)
df
# Out:
#     4   5   6   7
# 0   8   9  10  11
# 1  12  13  14  15

# %%
df= pd.read_csv("example.csv")
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
titanic= pd.read_csv("titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic= pd.read_csv("titanic_train.csv",sep=",")
titanic  #virgul ile ayirdik #csv dosyasinin icine girip bakarsaniz gorursunuz
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df= pd.read_csv("example.csv",nrows=3)
df
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
pd.read_csv("ornekcsv.csv")  #hata nedir?
#sep default a dikkat edin
#sep burda noktali virgul se bizde noktali virgul verecez
# Out:
#        a;b;c
# 0    78;12;1
# 1    78;12;2
# 2   78;324;3
# 3      7;2;4
# 4    88;23;5
# 5       6;2;
# 6    56;11;6
# 7     7;12;7
# 8    56;21;7
# 9    346;2;8
# 10     5;1;8
# 11  456;21;8
# 12   3;12;88

# %%
pd.read_csv("ornekcsv.csv",sep=";")
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
pd.read_csv("ornekcsv.csv",sep=";",index_col=0)
# Out:
#        b     c
# a
# 78    12   1.0
# 78    12   2.0
# 78   324   3.0
# 7      2   4.0
# 88    23   5.0
# 6      2   NaN
# 56    11   6.0
# 7     12   7.0
# 56    21   7.0
# 346    2   8.0
# 5      1   8.0
# 456   21   8.0
# 3     12  88.0

# %%
pd.read_csv("ornekcsv.csv",sep=";",index_col=1) 
#index atiyoruz #
# Out:
#        a     c
# b
# 12    78   1.0
# 12    78   2.0
# 324   78   3.0
# 2      7   4.0
# 23    88   5.0
# 2      6   NaN
# 11    56   6.0
# 12     7   7.0
# 21    56   7.0
# 2    346   8.0
# 1      5   8.0
# 21   456   8.0
# 12     3  88.0

# %%
pd.read_csv("ornekcsv.csv",sep=";")
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
df
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.to_csv("example4.csv")
df
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
pwd
# Out:
# 'c:\\Users\\bozta\\Рабочий стол\\Gİt_Hub\\Data-Science_REPO\\Data_Science\\Pandas'

# %%
#example4 diye dosya kaydettik

# %%
df.to_csv("dosyaismi/example5") # misal yazdim
#kopyalayacaginiz yeri kendimiz secebiliryoruz

# %%
df
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.to_excel("excel12.xlsx",sheet_name="sh1",index=False)
df.to_excel("excel12.xlsx",sheet_name="sh2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8864/1584834403.py in <module>
# ----> 1 df.to_excel("excel12.xlsx",sheet_name="sh1",index=False)
#       2 df.to_excel("excel12.xlsx",sheet_name="sh2")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ...

# %%
from sqlalchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8864/3124719862.py in <module>
# ----> 1 from sqlalchemy import create_engine
#
# ModuleNotFoundError: No module named 'sqlalchemy'
